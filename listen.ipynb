# %%
from music21 import converter

# %% [markdown]
# ## Generated Output

# %%
midi_g = converter.parse("generated_output.mid")

# %%
midi_g.show('midi')
# Out:
#                 <div id='midiPlayerDiv5969'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv5969');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %% [markdown]
# ## Auto Generated Output

# %%
midi_a = converter.parse("auto_generated_output.mid")

# %%
midi_a.show('midi')
# Out:
#                 <div id='midiPlayerDiv10437'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv10437');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
